# %% [markdown]
# Diagnostic Analysis using Python

# %% [markdown]
# #

# %%
# My GitHub repositories.
'https://github.com/oroy40051/NHS-ANALYTICS-PROJECT'
'https://github.com/oroy40051/mypythonactivity'
# Out:
# 'https://github.com/oroy40051/NHS-ANALYTICS-PROJECT'

# %% [markdown]
# #

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import and sense-check the actual_duration.csv data set as ad.
ad=pd.read_csv('actual_duration.csv')
print(ad.shape)
print(ad.dtypes)
print(ad.head())
print(ad.tail())
# Out:
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# ...

# %%
# Determine whether there are missing values.
ad.isnull()

# no missing values
# Out:
#         sub_icb_location_code  sub_icb_location_ons_code  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ...                       ...                        ...
# 137788                  False                      False
# 137789                  False                      False
# 137790                  False                      False
# 137791                  False                      False
# 137792                  False                      False
#
#         sub_icb_location_name  icb_ons_code  region_ons_code  \
# 0                       False         False            False
# 1                       False         False            False
# 2                       False         False            False
# ...

# %%
# Determine the metadata of the data set
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# Determine the descriptive statistics of the data set.
print(ad.describe())
# plot for desrciptive statistics

describe_num_ad = ad.describe()
describe_num_ad.reset_index(inplace=True)

describe_num_ad = describe_num_ad[describe_num_ad['index'] != 'count']
for i in describe_num_ad:
  if i in ['index']:
    continue
  sns.factorplot(x='index', y=i, data=describe_num_ad)
  plt.show()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
ar=pd.read_csv('appointments_regional.csv')

print(ar.shape)
print(ar.dtypes)
print(ar.head())
print(ar.tail())
# Out:
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# ...

# %%
# Determine whether there are missing values.
ar.isnull()

#no missing values
# Out:
#         icb_ons_code  appointment_month  appointment_status  hcp_type  \
# 0              False              False               False     False
# 1              False              False               False     False
# 2              False              False               False     False
# 3              False              False               False     False
# 4              False              False               False     False
# ...              ...                ...                 ...       ...
# 596816         False              False               False     False
# 596817         False              False               False     False
# 596818         False              False               False     False
# 596819         False              False               False     False
# 596820         False              False               False     False
#
#         appointment_mode  time_between_book_and_appointment  \
# 0                  False                              False
# ...

# %%
# Determine the metadata of the data set.
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# Determine the descriptive statistics of the data set.
print(ar.describe())

# plot for desrciptive statistics

describe_num_ar = ar.describe()
describe_num_ar.reset_index(inplace=True)

describe_num_ar = describe_num_ar[describe_num_ar['index'] != 'count']
for i in describe_num_ar:
  if i in ['index']:
    continue
  sns.factorplot(x='index', y=i, data=describe_num_ar)
  plt.show()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
nc=pd.read_excel('national_categories.xlsx')
print(nc.shape)
print(nc.dtypes)
print(nc.head())
print(nc.tail())
# Out:
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# ...

# %%
# Determine whether there are missing values.
nc.isnull()
# Out:
#         appointment_date  icb_ons_code  sub_icb_location_name  \
# 0                  False         False                  False
# 1                  False         False                  False
# 2                  False         False                  False
# 3                  False         False                  False
# 4                  False         False                  False
# ...                  ...           ...                    ...
# 817389             False         False                  False
# 817390             False         False                  False
# 817391             False         False                  False
# 817392             False         False                  False
# 817393             False         False                  False
#
#         service_setting  context_type  national_category  \
# 0                 False         False              False
# 1                 False         False              False
# ...

# %%
# Determine the metadata of the data set.
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Determine the descriptive statistics of the data set.
print(nc.describe())


# plot for desrciptive statistics

describe_num_nc = nc.describe()
describe_num_nc.reset_index(inplace=True)

describe_num_nc = describe_num_nc[describe_num_nc['index'] != 'count']
for i in describe_num_nc:
  if i in ['index']:
    continue
  sns.factorplot(x='index', y=i, data=describe_num_nc)
  plt.show()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.
num_loc=(ad['sub_icb_location_name'].nunique())
f"The number of locations in the data set is {num_loc}"
# Out:
# 'The number of locations in the data set is 106'

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count.
ad_1=ad['sub_icb_location_name']
ad_2=ad_1.value_counts()
top5=ad_2.head(5)
top5
# Out:
# NHS Norfolk and Waveney ICB - 26A                       1484
# NHS Kent and Medway ICB - 91Q                           1484
# NHS North West London ICB - W2U3Z                       1484
# NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y    1484
# NHS Greater Manchester ICB - 14L                        1484
# Name: sub_icb_location_name, dtype: int64

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.
print(nc['service_setting'].unique())
ss=(nc['service_setting'].nunique())
f"Number of  different service settings are\
 {ss}."
# Out:
# ['Primary Care Network' 'Other' 'General Practice' 'Unmapped'
#  'Extended Access Provision']
# 'Number of  different service settings are 5.'

# %%
# Determine the number of context types.
print(nc['context_type'].unique())
ct=(nc['context_type'].nunique())
f"Number of  different context types are\
 {ct}."
# Out:
# ['Care Related Encounter' 'Unmapped' 'Inconsistent Mapping']
# 'Number of  different context types are 3.'

# %%
# Determine the number of national categories.
print(nc['national_category'].unique())
nnc=(nc['national_category'].nunique())
f"Number of  different national categories are\
 {nnc}."
# Out:
# ['Patient contact during Care Home Round' 'Planned Clinics' 'Home Visit'
#  'General Consultation Acute' 'Structured Medication Review'
#  'Care Home Visit' 'Unmapped' 'Clinical Triage'
#  'Planned Clinical Procedure' 'Inconsistent Mapping'
#  'Care Home Needs Assessment & Personalised Care and Support Planning'
#  'General Consultation Routine'
#  'Service provided by organisation external to the practice'
#  'Unplanned Clinical Activity' 'Social Prescribing Service'
#  'Non-contractual chargeable work'
#  'Group Consultation and Group Education' 'Walk-in']
# 'Number of  different national categories are 18.'

# %%
# Determine the number of appointment status.
nas=ar['appointment_status'].nunique()
print(ar['appointment_status'].unique())
f"Number of  different appointment statuses are\
 {nas}."
# Out:
# ['Attended' 'DNA' 'Unknown']
# 'Number of  different appointment statuses are 3.'

# %% [markdown]
# Pandas was used for the import
#
# All three data sets have no outliers or missing values.Data is clean. Descriptive statistics are only available for 'count_of_appointments' as the other variables are all categorical. The top 5 locations with regards to number of records are:
# NHS Norfolk and Waveney ICB - 26A
# NHS Kent and Medway ICB - 91Q
# NHS North West London ICB - W2U3Z
# NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y
# NHS Greater Manchester ICB - 14L                        They all have 1484 records respectively.
# The number of locations in the data set is 106.
# The different service settings are: 'Primary Care Network','Other','General Practice'.'Unmapped'and
# 'Extended Access Provision'. There are 18 different national categories.
# 3 different context types:'Care Related Encounter' 'Unmapped' and 'Inconsistent Mapping'.
#
# 3 different appointment statuses: 'Attended' 'DNA'(did not attend) and 'Unknown'.
#
# 'nunique' function was used to determine number of unique 'categories' for the categorical variables.
# 'unique' function gave the names of the different
# categories.
#
# value_counts function was used to give the count of
# the different locations and thus records.
#
# The descriptive statistics were visualised for each data set using seaborn and a for loop.

# %% [markdown]
# #

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
ad['appointment_date'].head(5)
# Out:
# 0    01-Dec-21
# 1    01-Dec-21
# 2    01-Dec-21
# 3    01-Dec-21
# 4    01-Dec-21
# Name: appointment_date, dtype: object

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
nc['appointment_date'].head(5)
# Out:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Change the date format of ad['appointment_date'].
from datetime import datetime 
ad['appointment_date']=pd.to_datetime(ad['appointment_date'])
                                     

# View the DateFrame.
ad['appointment_date'].head(5)
# Out:
# 0   2021-12-01
# 1   2021-12-01
# 2   2021-12-01
# 3   2021-12-01
# 4   2021-12-01
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Change the date format of nc['appointment_date'].



# View the DateFrame.
nc['appointment_date'].head()
# Out:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Determine the minimum and maximum dates in the ad DataFrame.
# Use appropriate docstrings
adnc=pd.concat([ad,nc])
dmin=(adnc['appointment_date'].min())
dmax=(adnc['appointment_date'].max())

f"The appointments were between the dates\
            {dmin} and {dmax}"
# Out:
# 'The appointments were between the dates            2021-08-01 00:00:00 and 2022-06-30 00:00:00'

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# For each of these service settings, determine the number of records available for the period and location
# View the output
nc2=nc[(nc['appointment_date'] > '2022/01/01') &
        (nc['appointment_date']< '2022/06/01')]\
.sort_values('appointment_date',ascending=True)
print(nc2)

nc3=nc2[nc2['sub_icb_location_name']\
       .apply(lambda x:'NHS North West London'\
       in x)]
print(nc3['sub_icb_location_name'])

nc4=nc3.groupby('service_setting')\
[['sub_icb_location_name']].count()\
.sort_values('sub_icb_location_name',\
            ascending=False)
# Out:
#        appointment_date icb_ons_code  \
# 615657       2022-01-02    E54000030
# 457295       2022-01-02    E54000044
# 457294       2022-01-02    E54000044
# 770222       2022-01-02    E54000042
# 439156       2022-01-02    E54000057
# ...                 ...          ...
# 763768       2022-05-31    E54000034
# 763769       2022-05-31    E54000034
# 763770       2022-05-31    E54000034
# 763762       2022-05-31    E54000034
# 816470       2022-05-31    E54000054
#
#                                     sub_icb_location_name  \
# 615657                    NHS South East London ICB - 72Q
# 457295  NHS Buckinghamshire Oxfordshire and Berkshire ...
# 457294  NHS Buckinghamshire Oxfordshire and Berkshire ...
# 770222        NHS Hampshire and Isle Of Wight ICB - D9Y0V
# 439156                   NHS Greater Manchester ICB - 14L
# ...                                                   ...
# 763768                            NHS Frimley ICB - D4U1Y
# ...

# %%
print(nc4)
# Out:
#                            sub_icb_location_name
# service_setting
# General Practice                            2080
# Other                                       1307
# Primary Care Network                        1261
# Extended Access Provision                   1076
# Unmapped                                     150

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Number of appointments per month == sum of count_of_appointments by month.
# Use the groupby() and sort_values() functions.
ar.groupby('appointment_month')\
[['count_of_appointments']].sum()\
.sort_values('count_of_appointments',\
            ascending=False)

# November 2021 had the
# Out:
#                    count_of_appointments
# appointment_month
# 2021-11                         30405070
# 2021-10                         30303834
# 2022-03                         29595038
# 2021-09                         28522501
# 2020-10                         28301932
# 2022-05                         27495508
# 2021-03                         27225424
# 2020-01                         27199296
# 2021-06                         26784182
# 2020-09                         26714255
# 2022-06                         25828078
# 2021-07                         25739219
# 2022-01                         25635474
# 2022-02                         25355260
# 2021-12                         25140776
# 2020-11                         25061602
# 2020-02                         24104621
# 2020-03                         24053468
# 2022-04                         23913060
# 2021-04                         23879932
# 2021-08                         23852171
# ...

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month.
ar_1=ar['appointment_month']
ar_2=ar_1.value_counts()

print(ar_2)
# Out:
# 2020-03    21350
# 2020-01    20889
# 2021-11    20766
# 2020-02    20689
# 2021-10    20562
# 2022-03    20532
# 2021-09    20441
# 2021-12    20393
# 2022-05    20276
# 2022-06    20231
# 2022-01    20225
# 2022-02    20133
# 2020-10    20122
# 2022-04    20073
# 2020-09    20043
# 2021-07    19899
# 2021-06    19814
# 2021-08    19786
# 2020-11    19675
# 2020-07    19502
# 2021-04    19452
# 2020-12    19394
# 2021-05    19384
# 2021-03    19369
# 2021-01    19319
# 2020-08    19247
# 2020-04    19124
# 2021-02    18949
# 2020-06    18844
# 2020-05    18338
# Name: appointment_month, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# #Summary
# For the first question in order to  find the maximum and minimum dates two tables were stacked using the concat function (ad and nc) as they contain the largest and correct range of date values.
# The appointment date of the ad dataframe was then converted to the same format as the nc data frame
# (YYYY-MM-DD) and was also converted into a datetime
# object using the datetime module allowing for better analyis.
# For the second question we filtered the nc dataframe to get the values from 1st of January to 1st of June 2022. We then used a lambda function to find locations containing the specific string of 'NHS North West London ICB - W2U3Z'. We then used the groupby function to determine the number of records for each service setting with the given location and time period.We then sorted by largest number of records first to get the correct data needed.
#
# For the third question we used the groupby function with the appointment months to find the month with the highest number of appointments. We see that November 2021 had the highest number of appointments.
#
# For the fourth question we filtered the ar dataset to show the appointment month. We then used the value_counts function to find the number of records for each month.

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Aggregate on monthly level and determine the sum of records per month.
nc1=pd.read_excel('national_categories.xlsx')

# Change the data type of the appointment month to string to allow for easier plotting.
nc1['appointment_month']=(nc1['appointment_month'])
print(nc1.dtypes)


nc_ss=nc1.groupby(['appointment_month','service_setting'])['count_of_appointments'].\
sum().reset_index()

# View output.
nc_ss.head()
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %% [markdown]
# **Service settings:**

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create a lineplot.
sns.lineplot(x='appointment_month',y='count_of_appointments',hue='service_setting',ci=None,data=nc_ss)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
nc_ct=nc1.groupby(['context_type','appointment_month'])['count_of_appointments'].\
sum().reset_index()

# View output.
nc_ct.head()
# Out:
#              context_type appointment_month  count_of_appointments
# 0  Care Related Encounter           2021-08               20255235
# 1  Care Related Encounter           2021-09               24404251
# 2  Care Related Encounter           2021-10               26125201
# 3  Care Related Encounter           2021-11               26282778
# 4  Care Related Encounter           2021-12               21798612

# %%
# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot.
sns.lineplot(x='appointment_month',y='count_of_appointments',hue='context_type',ci=None,data=nc_ct)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 
nc_nc=nc1.groupby(['national_category','appointment_month'])['count_of_appointments'].\
sum().reset_index()


# View output.
nc_nc.head()
# Out:
#                                    national_category appointment_month  \
# 0  Care Home Needs Assessment & Personalised Care...           2021-08
# 1  Care Home Needs Assessment & Personalised Care...           2021-09
# 2  Care Home Needs Assessment & Personalised Care...           2021-10
# 3  Care Home Needs Assessment & Personalised Care...           2021-11
# 4  Care Home Needs Assessment & Personalised Care...           2021-12
#
#    count_of_appointments
# 0                  29676
# 1                  33503
# 2                  32441
# 3                  38827
# 4                  34653

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot.
sns.lineplot(x='appointment_month',y='count_of_appointments',hue='national_category',ci=None,data=nc_nc)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021):**

# %%
print(nc1.dtypes)
# Create a separate data set that can be used in future weeks. 
nc_ss_day=nc1.groupby(['appointment_date','appointment_month','service_setting'])['count_of_appointments'].sum().reset_index()

# View output.
nc_ss_day.head()
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#   appointment_date appointment_month            service_setting  \
# 0       2021-08-01           2021-08  Extended Access Provision
# 1       2021-08-01           2021-08           General Practice
# 2       2021-08-01           2021-08                      Other
# 3       2021-08-01           2021-08       Primary Care Network
# 4       2021-08-01           2021-08                   Unmapped
#
#    count_of_appointments
# 0                    438
# 1                   3411
# 2                    401
# 3                    323
# 4                   1054

# %%
# Look at August 2021 in more detail to allow a closer look.
# Create a lineplot.
nc_ss_day1=nc_ss_day[nc_ss_day['appointment_month']\
                     =='2021-08']
nc_ss_aug=nc_ss_day1[nc_ss_day1['service_setting'] !=\
'General Practice']

sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_day1,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %%
sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_aug,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Look at October 2021 in more detail to allow a closer look.
# Create a lineplot.
nc_ss_day2=nc_ss_day[nc_ss_day['appointment_month']\
                     =='2021-10']
nc_ss_oct=nc_ss_day[nc_ss_day['service_setting'] !=\
'General Practice']

sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_day2,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %%
sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_oct,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %% [markdown]
# **Winter (January 2022):**

# %%
# Look at January 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_ss_day3=nc_ss_day[nc_ss_day['appointment_month']\
                     =='2022-01']
nc_ss_day3

nc_ss_jan=nc_ss_day3[nc_ss_day3['service_setting'] !=\
'General Practice']

sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_day3,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %%
sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_jan,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %% [markdown]
# **Spring (April 2022):**

# %%
# Look at April 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_ss_day4=nc_ss_day[nc_ss_day['appointment_month']\
                     =='2022-04']
nc_ss_apr=nc_ss_day4[nc_ss_day4['service_setting'] !=\
'General Practice']


sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_day4,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %%
sns.lineplot(x='appointment_date',y='count_of_appointments',\
             hue='service_setting',data=nc_ss_apr,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_date', ylabel='count_of_appointments'>

# %% [markdown]
# #

# %% [markdown]
# #Summary:
# Printing the data types for the nc dataframe we see that the appointment month is a string and the appointment date is a datetime object as required for ease of visualisation.
# Dataframes for service settings, context types and national categories were created by using the groupby function to group each one of them with the appointment month and to show the total number of of appointments per month by aggregating the count of appointments using the sum function.
#
# We then employed seaborn to visualise the total number of appointments per month by creating a time-series with three variables, where in each case the x-axis was the appointment month, the y-axis was the total number of appointments and a comparison between the different categories was done by a different colour for each category (i.e different colours for the different service settings).
#
# For the service settings we see that the most appointments are with the General Practice by far with peaks at Nov-2021 and Mar-2022.
#
# For the context types we see that the most common context type is care related encounters. Inconsistent and unmapped encounters are much lower which is a positive in regards to error control.
#
# Care related encounters also have peaks at Nov-2021 and Mar-2022.
#
# For the national categories General Consultation, Acute and group education are the top three respectively following a similar peak pattern as the service settings and context types.
#
#
# We then dived deeper into the service settings by looking at the number of appointments per season.
# We used the group by function to group by appointment date and appointment aggregated on the sum of the count of appointments. We then filtered by a specific month and used seabron to visualise the trends for the different service settings using the appointment dates
# for that month month and the number of appointments. This was displayed as a time series plot.
# We see that each season follows a similar trend.
# There is a sharp periodic increase from a minimum to a maximum every 4 days of the month.
# Clearly General Practice is the most common once again.
# It would be better to do an analysis on the rest of the service settings separately from the general practice for better insights.
#
# We create time series plots filtering out the general practice setting type.
#
# Now we have some interesting insights. All the seasons are very similar except Autumn of 2021. Here we see a rapidly fluctuating time series plot and a overall decreasing trend as the month progresses.
# We can see that the NHS hits high levels of appointments during this time, which could be due to the increase in COVID-19 cases in this season.
#
# Unmapped appointments is the 'best of the rest' and once again this is something that needs to be address with regards to error control and data management.

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
tweets=pd.read_csv('tweets.csv')

# View the DataFrame.
tweets1=pd.DataFrame(tweets)
print(tweets1)
# Out:
#                  tweet_id  \
# 0     1567629223795527681
# 1     1567582846612553728
# 2     1567582787070304256
# 3     1567582767625428992
# 4     1567582720460570625
# ...                   ...
# 1169  1567583004209332227
# 1170  1567582945342267393
# 1171  1567582936014241792
# 1172  1567582892892782592
# 1173  1567582846847533058
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# ...

# %%
# Explore the metadata.
import json
from bs4 import BeautifulSoup
soup=BeautifulSoup('metadata_nhs')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    metadata_nhs
#   </p>
#  </body>
# </html>

# %%
# Explore the data set.
tweets1.describe()
tweets1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer.
tweets1['tweet_retweet_count'].value_counts()
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64

# %%
tweets1['tweet_favorite_count'].value_counts()
# Out:
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %%
# Create a new DataFrame containing only the text.
tweets_text=tweets1[['tweet_full_text','tweet_entities','tweet_entities_hashtags','tweet_metadata','tweet_lang']]
# View the DataFrame
print(tweets_text)
# Out:
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                              RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
# Loop through the messages, and create a list of values containing the # symbol.
tags=[]
for y in [x.split(' ') for x in tweets_text['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())
            
tag=pd.Series(tags)
tag1=tag.value_counts()

# %%
# Display the first 30 records.
print(tag1.head(30))
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %%
# Convert the series to a DataFrame in preparation for visualisation.
tag2=pd.DataFrame(tag1).reset_index()
tag2.columns
# Rename the columns.
tag2.columns=['Word','Count']

# %%
# Fix the count datatype.
tag2

# View the result.
tag2.dtypes
tag2.head()
tag2.info()
tag2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754 entries, 0 to 1753
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    1754 non-null   object
#  1   Count   1754 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 27.5+ KB
#              Count
# count  1754.000000
# mean      2.470353
# std      17.462844
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max     716.000000

# %%
# Display records where the count is larger than 10.
tag3=tag2[(tag2['Count']>10)]
tag3
# Out:
#                            Word  Count
# 0                   #healthcare    716
# 1                       #health     80
# 2                     #medicine     41
# 3                           #ai     40
# 4                          #job     38
# 5                      #medical     35
# 6                     #strategy     30
# 7               #pharmaceutical     28
# 8                #digitalhealth     25
# 9                       #pharma     25
# 10                   #marketing     25
# 11                  #medtwitter     24
# 12                     #biotech     24
# 13     #competitiveintelligence     24
# 14                       #meded     23
# 15                     #vaccine     18
# 16                      #hiring     18
# 17                        #news     17
# 18             #machinelearning     17
# 19                  #technology     17
# 20                 #coronavirus     16
# 21             #womeninmedicine     16
# 22                       #covid     16
# ...

# %%
# Create a Seaborn barplot indicating records with a count >10 records.
tag3_long=tag3.melt(var_name='Word',value_name='Count')
print(tag3.head())
sns.barplot(x='Word',y='Count',data=tag3)
# Out:
#           Word  Count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %%
# least common tweets
sns.barplot(x='Word',y='Count',data=tag3.tail())
# Out:
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %%
# after these 'middle values' the rest is very similar
#so do a separate plot for this.

print(tag3.iloc[6:15,:])
sns.barplot(x='Word',y='Count',data=tag3.iloc[6:15,:])
# Out:
#                         Word  Count
# 6                  #strategy     30
# 7            #pharmaceutical     28
# 8             #digitalhealth     25
# 9                    #pharma     25
# 10                #marketing     25
# 11               #medtwitter     24
# 12                  #biotech     24
# 13  #competitiveintelligence     24
# 14                    #meded     23
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %%
# Create the plot.
tag4=tag3[(tag3['Count']>30)]


# View the barplot.

# top 6
sns.barplot(x='Word',y='Count',data=tag4)
# Out:
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %%
# top 5 excluding #healthcare as it is a positive outlier
# View the barplot.
sns.barplot(x='Word',y='Count',data=tag3.iloc[1:6,:])
# Out:
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %% [markdown]
# #

# %% [markdown]
# We import the tweets data using panda and explore the metadata using the BeautifulSoup module by converting it to a beautiful soup object and then applying the prettify function.
#
# We explore the number of retweets and favourites column individually. Once again using the robust value_counts function we see the word healthcare has the most retweets and favourites, however the world health is second and closer than in other catgories in the retweets column.
#
# There is not much use in exploring these columns individually as they are a metric of popularity and display the same information as the count of tweet hashtags which we explore anyway. Also without the corresponding word there is no use of the columns individually.
#
# We then create a dataframe consisting only of string values and use a for loop to find all the word with the '#' symbol. We then convert the resulting series into a dataframe using pandas, rename the columns and prepare for analysis.
#
# We create a barplot using seaborn to find the hashtags with more than 30 counts. The resulting bar plot is very cluttered and hard to intrepret.
# We thus decompose the bar plot.
# We create a barplot for the last 5 values. Interestingly we see drugs and nurses are present, this could indicate the lack of awareness of health problems due to recreational drug use aswell as the under-recognition of the efforts of nurses in the NHS.
#
# We see that after the 'meded' hashtag the counts are very similar so we explore the 'middle values' to be able to obtain insights of any value.
#
# We then create a plot for the hashtags with more than 30 counts and see healthcare is by far the greatest.
# This is a positive outlier thus we create a top 5 plot excluding this. Health is a expected synonym of the word healthcare. Interesting insights we find are the words 'ai' and 'job' which could indicate the boom in machine learning and artificial intelligence use in the medical industry. The word 'job' could indicate the high demand for work in the healthcare or medical industry.

# %% [markdown]
# ### Investigate the main cencerns posed by the NHS.

# %%
# Load the appointments_regional.csv file.
# Filter the data set to only look at data from 2021-08 onwards.

ar_1=ar[ar['appointment_month']>='2021-08']

# View the DataFrame.
ar_1.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3652    E54000034           2021-08           Attended       GP
# 3653    E54000034           2021-08           Attended       GP
# 3654    E54000034           2021-08           Attended       GP
# 3655    E54000034           2021-08           Attended       GP
# 3656    E54000034           2021-08           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3652     Face-to-Face                             1 Day                   6553
# 3653     Face-to-Face                    15  to 21 Days                   2390
# 3654     Face-to-Face                       2 to 7 Days                  10547
# 3655     Face-to-Face                    22  to 28 Days                    937
# 3656     Face-to-Face                     8  to 14 Days                   4961

# %%
# Print the min and max dates.
print(ar_1['appointment_month'].min())
print(ar_1['appointment_month'].max())
# Out:
# 2021-08
# 2022-06

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.
ar_agg=ar_1[['appointment_month','hcp_type',\
              'appointment_status','appointment_mode',\
              'time_between_book_and_appointment','count_of_appointments']]
hcp_typ=ar_agg.groupby('hcp_type')['count_of_appointments'].sum().reset_index()
app_stat=ar_agg.groupby('appointment_status')['count_of_appointments'].sum().reset_index()
app_month=ar_agg.groupby('appointment_month')['count_of_appointments'].sum().reset_index()
tbbaa=ar_agg.groupby('time_between_book_and_appointment')['count_of_appointments'].sum().reset_index()

# View the DataFrame.
tbbaa
# Out:
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day               25872974
# 1                    15  to 21 Days               19454328
# 2                       2 to 7 Days               60734100
# 3                    22  to 28 Days               11430584
# 4                     8  to 14 Days               37507051
# 5                 More than 28 Days                9880538
# 6                          Same Day              130976642
# 7            Unknown / Data Quality                 190553

# %%
# Determine the total number of appointments per month.
ar_df=ar_1[['appointment_month','hcp_type',\
              'appointment_status','appointment_mode',\
              'time_between_book_and_appointment','count_of_appointments']]

ar_df_1=ar_df.groupby('appointment_month')['count_of_appointments'].sum().reset_index()
ar_df_1['average_utilisation']=(ar_df_1['count_of_appointments']/30).round(1)
ar_df_1.head()
# Add a new column to indicate the average utilisation of services.
ar_df_1.min()
# Monthly aggregate / 30 to get to a daily value.


# View the DataFrame.
# Out:
# appointment_month         2021-08
# count_of_appointments    23852171
# average_utilisation      795072.4
# dtype: object

# %%
# Convert the appointment_month to string data type for ease of visualisation.

ar_df_2=ar_df_1.astype({"appointment_month":str})
# Create a lineplot with Seaborn.
ar_df_2.dtypes
sns.lineplot(x='appointment_month',y='count_of_appointments',\
            data=ar_df_2)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %%
# Plot monthly capacity utilisation.


# Create a lineplot.
sns.lineplot(x='appointment_month',y='average_utilisation',data=ar_df_2)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='average_utilisation'>

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Create a line plot to answer the question.

sns.lineplot(x='appointment_month',y="count_of_appointments",hue='hcp_type', data=ar_agg,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create a line plot to answer the question.
sns.lineplot(x='appointment_month',y="count_of_appointments",hue='appointment_status', data=ar_agg,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Create a line plot to answer the question.
sns.lineplot(x='appointment_month',y="count_of_appointments",hue='appointment_mode', data=ar_agg,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Create a line plot to answer the question.
sns.lineplot(x='appointment_month',y="count_of_appointments",hue='time_between_book_and_appointment', data=ar_agg,ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.
nc1.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Create a new DataFrame consisting of the month of appointment and the number of appointments.
nc_ss
# View the DataFrame.
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08           General Practice               21575852
# 2            2021-08                      Other                 449101
# 3            2021-08       Primary Care Network                 432448
# 4            2021-08                   Unmapped                1233843
# 5            2021-09  Extended Access Provision                 187906
# 6            2021-09           General Practice               25940821
# 7            2021-09                      Other                 527174
# 8            2021-09       Primary Care Network                 530485
# 9            2021-09                   Unmapped                1336115
# 10           2021-10  Extended Access Provision                 209539
# 11           2021-10           General Practice               27606171
# ...

# %%
# Create a boxplot to investigate spread of service settings.
sns.boxplot(x='service_setting',y='count_of_appointments',data=nc_ss)
# Out:
# <AxesSubplot:xlabel='service_setting', ylabel='count_of_appointments'>

# %%
# Create a boxplot to investigate the service settings without GP.
nc_ss2=nc_ss[nc_ss.service_setting !='General Practice'].reset_index()
sns.boxplot(x='service_setting',y='count_of_appointments',data=nc_ss2)
# Out:
# <AxesSubplot:xlabel='service_setting', ylabel='count_of_appointments'>

# %%
#Time series plot on GP

nc_gp_fore=nc1[['appointment_month','service_setting','count_of_appointments']]

nc_gp_fore1=nc_gp_fore[nc_gp_fore['service_setting']=='General Practice']
nc_gp_fore1.plot(x='appointment_month',y='count_of_appointments',figsize=(12, 4))
plt.legend(loc='best')
plt.title('Time series plot for number of GP appointments')
plt.show(block=False)
nc_gp_fore1.dtypes
# Out:
# appointment_month        object
# service_setting          object
# count_of_appointments     int64
# dtype: object

# %% [markdown]
# #

# %% [markdown]
# ### Recommendations

# %% [markdown]
# We see that during April 2022 and around Christmas season in 2021 the average utilisation is less.
#     from August 2021 to November the utilisation gradually increases. while after April 2022 into the summer months the utilisation gradually increases. We however see a overall decreasing trend. This indicates that the issue is not with the number of staff but a mismatch of hours creating times of extreme stress on the healthcare system. Re-distributing from April and the Christmas period could address this issue.
#   Healthcare professionals follow a similar trend with GP being the most common. Hiring more General practioners could address this.
#   The number of DNA and unknown visits are significantly less than attended ones which is a positive indication.
#
#  We see a peak of inperson visits in October 2021 while telephone appointments has a slight dip.
#  During November 2021 and January 2022 telephone appointments increase slightly while in person visits are lower than usual. From March 2022 they both follow very similar trends.
#  We can ignore the other categories as they are insignifcant in comparison. We could group them all together as in person and not in person, this is not necessary however as they would hardly impact the trend of the telephone and inperson categories.
#
#  We see quite clearly that same day appointments are significantly more common than other ones. As the time between booking and appointment increases the number  of appointments decreases. This indicates a negative correlation but not necessarily a causation. We however mention correlation with caution as the number of days is treated as a categorical variable instead of a numerical one. In order to reduce workload during busy months we can reduce or stop same day appointments in the givin busy time-period.
#
#
# GP is the most common service setting therefore once again we look at the other settings as when GP is included the visualisation of the other settings in a boxplot is not intrepetable.
# We see there is a large number of unmapped appointments furthur indicating the need for better data handling and administration services.
# There are no outliers in the data while unmapped has the greatest range.
#
# Looking at the time-series plot for the number of appointments we see a general strong positive trend between the appointment months and the number of appointments. This needs to be addressed as the rapid growth may overwhelm the NHS.
